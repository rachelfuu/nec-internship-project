# %%
import pandas as pd
import pymysql
import logging
import sshtunnel
from sshtunnel import SSHTunnelForwarder
import os.path

# %%
# You will need to add your SSH public key and database password to connect.
ssh_host = 'vfsmghnecweb01.fsm.northwestern.edu'
ssh_username = 'efa3001'
db_server = 'vfsmghnecdb01.fsm.northwestern.edu'
database_username = 'efa3001'
ssh_pkey = 'C:\\Users\\16262\\Desktop\\NCDS-NEC_Data_Internship\\5-16-privkey-openSSH'
database_password = 'E%H2)h.nPevc<a>&'
database_name = 'nec_dw'
localhost = '127.0.0.1'

# %%
def open_ssh_tunnel(verbose=False):
    """Open an SSH tunnel and connect using a username and password.
    
    :param verbose: Set to True to show logging
    :return tunnel: Global SSH tunnel connection
    """
    
    if verbose:
        sshtunnel.DEFAULT_LOGLEVEL = logging.DEBUG
    
    global tunnel
    tunnel = SSHTunnelForwarder(
        (ssh_host, 22),
        ssh_username = ssh_username,
        ssh_pkey = ssh_pkey,
        remote_bind_address = (db_server, 3306)
    )
    
    tunnel.start()

# %%
def mysql_connect():
    """Connect to a MySQL server using the SSH tunnel connection
    
    :return connection: Global MySQL database connection
    """
    
    global connection
    
    connection = pymysql.connect(
        host = localhost,
        user = database_username,
        passwd = database_password,
        db = database_name,
        port = tunnel.local_bind_port
    )

# %%
def run_query(sql):
    """Runs a given SQL query via the global database connection.
    
    :param sql: MySQL query
    :return: Pandas dataframe containing results
    """
    
    return pd.read_sql_query(sql, connection)

# %%
def mysql_disconnect():
    """Closes the MySQL database connection.
    """
    
    connection.close()

# %%
def close_ssh_tunnel():
    """Closes the SSH tunnel connection.
    """
    
    tunnel.close

# %%
open_ssh_tunnel()

# %%
mysql_connect()

# %%
#Below: Exploring the relationship between Funding and Success Ratings

# %%
#grabbing Reports, Projects, and Project Funding Tables
rep_df, proj_df, fund_df = run_query("SELECT * FROM Reports"), run_query("SELECT * FROM Projects"), run_query("SELECT * FROM ProjectFunding")

# %%
#grabbing Staff Activities table
staffact_df = run_query("SELECT * FROM StaffActivities")
staffact_df.head()
# Out:
#    ActivityID                                              Title  \
# 0        9649   PubMed Training; Merck staff training; 2/14/2019
# 1        9664         LAPL El Sereno Mental Health Support Group
# 2        9665         LAPL El Sereno Mental Health Support Group
# 3        9666                   MedlinePlus training-Los Angeles
# 4        9667  Serving Diverse Communities: Finding Data on H...
#
#                                          Description  RegionOfficeID  \
# 0  Purpose is to introduce PubMed to Merck staff;...             3.0
# 1  Nora Franco conducted a site visit to the El S...            13.0
# 2  Nora Franco conducted a follow-up site visit t...            13.0
# 3  One on one MedlinePlus training with nursing s...            13.0
# 4  An online, asynchronous course designed to int...             2.0
#
#     StartDate     EndDate  ActivityWasConductedOnline  \
# 0  2019-02-14  2019-02-14                         1.0
# 1  2019-01-16  2019-01-16                         0.0
# 2  2019-02-26  2019-02-26                         0.0
# 3  2019-02-06  2019-02-06                         0.0
# 4  2019-03-01  2019-03-01                         1.0
#
#    ActivityWasConductedInPerson       County  ActivityHowSuccessfulID  ...  \
# 0                           0.0    Allegheny                      4.0  ...
# 1                           1.0  Los Angeles                      4.0  ...
# 2                           1.0  Los Angeles                      5.0  ...
# 3                           1.0  Los Angeles                      5.0  ...
# 4                           0.0      Johnson                      4.0  ...
#
#    TrainingWasProvided                      AddressStreet  \
# 0                  1.0                    200 Scaife Hall
# 1                  0.0               5226 Huntington Dr S
# 2                  0.0               5226 Huntington Dr S
# 3                  1.0  Ronald Reagan UCLA Medical Center
# 4                  1.0                    600 Newton Road
#
#    AddressApartmentSuite  AddressCity  AddressState    Zip  \
# 0       3550 Terrace St.   Pittsburgh            PA  15261
# 1                         Los Angeles            CA  90032
# 2                         Los Angeles            CA  90032
# 3     757 Westwood Plaza  Los Angeles            CA  90095
# 4                           Iowa City            IA  52242
#
#          116CongressDistrict  GeocodedLatitude GeocodedLongitude ModifiedDate
# 0                Unavailable           0.00000          0.000000   2020-03-05
# 1  Congressional District 34          34.08951       -118.168655   2020-03-05
# 2  Congressional District 34          34.08951       -118.168655   2020-03-05
# 3                Unavailable           0.00000          0.000000   2020-03-05
# 4   Congressional District 2          41.66302        -91.547540   2020-03-05
#
# [5 rows x 27 columns]

# %%
#removing null success values
staffact_success_df = staffact_df[staffact_df["ActivityHowSuccessfulID"] > 0.0]
staffact_success_df
# Out:
#       ActivityID                                              Title  \
# 0           9649   PubMed Training; Merck staff training; 2/14/2019
# 1           9664         LAPL El Sereno Mental Health Support Group
# 2           9665         LAPL El Sereno Mental Health Support Group
# 3           9666                   MedlinePlus training-Los Angeles
# 4           9667  Serving Diverse Communities: Finding Data on H...
# ...          ...                                                ...
# 3729       33844                              Web Working Group YR4
# 3730       33846  3rd quarter call with UIC College of Nursing: ...
# 3731       33848                        NNLM PNR - Facebook - Y5 Q4
# 3732       33850                         NNLM PNR - Twitter - Y5 Q4
# 3733       34002                                     NNLM Day @ MLA
#
#                                             Description  RegionOfficeID  \
# 0     Purpose is to introduce PubMed to Merck staff;...             3.0
# 1     Nora Franco conducted a site visit to the El S...            13.0
# 2     Nora Franco conducted a follow-up site visit t...            13.0
# 3     One on one MedlinePlus training with nursing s...            13.0
# 4     An online, asynchronous course designed to int...             2.0
# ...                                                 ...             ...
# 3729    Monthly meetings of web site issues and updates             2.0
# 3730  Met virtually with Krista Jones, principal for...             2.0
# 3731  14 posts in February.\n18 posts in March.\n10 ...            12.0
# 3732  FEB 2021: 18 Tweets; 3,727 Tweet impressions; ...            12.0
# 3733  Information about the work of the Region 7 off...             7.0
#
#        StartDate     EndDate  ActivityWasConductedOnline  \
# 0     2019-02-14  2019-02-14                         1.0
# 1     2019-01-16  2019-01-16                         0.0
# 2     2019-02-26  2019-02-26                         0.0
# 3     2019-02-06  2019-02-06                         0.0
# 4     2019-03-01  2019-03-01                         1.0
# ...          ...         ...                         ...
# 3729  2019-05-01  2019-05-01                         1.0
# 3730  2021-01-15  2021-01-15                         1.0
# 3731  2021-02-02  2021-02-02                         1.0
# 3732  2021-02-01  2021-02-01                         1.0
# 3733  2021-05-17  2021-05-17                         1.0
#
#       ActivityWasConductedInPerson       County  ActivityHowSuccessfulID  ...  \
# 0                              0.0    Allegheny                      4.0  ...
# 1                              1.0  Los Angeles                      4.0  ...
# 2                              1.0  Los Angeles                      5.0  ...
# 3                              1.0  Los Angeles                      5.0  ...
# 4                              0.0      Johnson                      4.0  ...
# ...                            ...          ...                      ...  ...
# 3729                           0.0      Johnson                      5.0  ...
# 3730                           0.0      Johnson                      5.0  ...
# 3731                           0.0         King                      3.0  ...
# 3732                           0.0         King                      3.0  ...
# 3733                           0.0    Worcester                      3.0  ...
#
#       TrainingWasProvided                      AddressStreet  \
# 0                     1.0                    200 Scaife Hall
# 1                     0.0               5226 Huntington Dr S
# 2                     0.0               5226 Huntington Dr S
# 3                     1.0  Ronald Reagan UCLA Medical Center
# 4                     1.0                    600 Newton Road
# ...                   ...                                ...
# 3729                  1.0                      600 Newton Rd
# 3730                  0.0                      600 Newton Rd
# 3731                  0.0                 1959 NE Pacific St
# 3732                  0.0                 1959 NE Pacific St
# 3733                  0.0                     401 Avalon Way
#
#       AddressApartmentSuite  AddressCity  AddressState    Zip  \
# 0          3550 Terrace St.   Pittsburgh            PA  15261
# 1                            Los Angeles            CA  90032
# 2                            Los Angeles            CA  90032
# 3        757 Westwood Plaza  Los Angeles            CA  90095
# 4                              Iowa City            IA  52242
# ...                     ...          ...           ...    ...
# 3729                           Iowa City            IA  52242
# 3730                           Iowa City            ID  52242
# 3731                             Seattle            WA  98195
# 3732                             Seattle            WA  98195
# 3733                          Shrewsbury            MA  01545
#
#             116CongressDistrict  GeocodedLatitude GeocodedLongitude  \
# 0                   Unavailable           0.00000          0.000000
# 1     Congressional District 34          34.08951       -118.168655
# 2     Congressional District 34          34.08951       -118.168655
# 3                   Unavailable           0.00000          0.000000
# 4      Congressional District 2          41.66302        -91.547540
# ...                         ...               ...               ...
# 3729                       None               NaN               NaN
# 3730                       None               NaN               NaN
# 3731                       None               NaN               NaN
# 3732                       None               NaN               NaN
# 3733                       None               NaN               NaN
#
#      ModifiedDate
# 0      2020-03-05
# 1      2020-03-05
# 2      2020-03-05
# 3      2020-03-05
# 4      2020-03-05
# ...           ...
# 3729   2021-04-22
# 3730   2021-04-21
# 3731   2021-04-21
# 3732   2021-04-21
# 3733   2021-05-20
#
# [3734 rows x 27 columns]

# %%
#checking distribution of ratings of success
success_counts = staffact_success_df.groupby(["ActivityHowSuccessfulID"])['ActivityHowSuccessfulID'].count()
success_counts
# Out:
# ActivityHowSuccessfulID
# 1.0       2
# 2.0      27
# 3.0     485
# 4.0    2133
# 5.0    1087
# Name: ActivityHowSuccessfulID, dtype: int64

# %%
#mysql_disconnect()
#close_ssh_tunnel()

# %%
# # Write the data frame to a tab-seperated text file

# import os  

# file_path = "C:\\Users\\16262\\Desktop\\nec-internship-project"

# if not os.path.exists(file_path):
#     os.mkdir(file_path)

# output_file = 'NNLM_final_reports_sample.tsv'
# complete_fn = os.path.join(file_path, output_file)
# df.to_csv(complete_fn, sep = '\t',index=False)
